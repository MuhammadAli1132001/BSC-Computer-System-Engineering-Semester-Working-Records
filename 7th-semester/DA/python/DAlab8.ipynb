# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples)

# %%
plt.plot(yield_apples);

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.933]

# %%
plt.plot(years, yield_apples);

# %%
plt.plot(years, yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields In Pakistan")
plt.legend(['Apples', 'Oranges']);

# %%
# plt.figure(figsize=(12, 6))
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='x')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Pakistan")
plt.legend(['Apples', 'Oranges']);

# %%
data_2 = data_2.groupedby('month').sum()

# %%
import matplotlib.pyplot as plt
d = covid_df.date
d
plt.plot(data['data'],data['new_cases'])
plt.plot(['date','new_deaths'])
plt.xlabel('days-wise')
plt.ylabel('newt_cases')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 d = covid_df.date
#       3 d
#       4 plt.plot(data['data'],data['new_cases'])
#
# NameError: name 'covid_df' is not defined
