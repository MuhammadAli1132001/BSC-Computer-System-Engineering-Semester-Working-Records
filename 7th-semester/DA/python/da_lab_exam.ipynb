# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rooms_record = pd.read_csv('exam_data_file.csv')

# %%
rooms_record.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
rooms_record.loc[999:1010]
# Out:
#       Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 999          999  8001400340  20140924T000000  289000.0       3.0       2.00
# 1000        1000  3131200640  20150427T000000  700000.0       4.0       2.00
# 1001        1001   984000710  20141022T000000  270000.0       3.0       2.00
# 1002        1002  4167300350  20140508T000000  258000.0       4.0       1.75
# 1003        1003  2826049282  20140614T000000  530000.0       3.0       2.50
# 1004        1004  8946750030  20141218T000000  245000.0       3.0       2.25
# 1005        1005   461004720  20150422T000000  563000.0       3.0       2.00
# 1006        1006  7852090810  20141119T000000  515000.0       3.0       2.50
# 1007        1007  9264960340  20140617T000000  325000.0       4.0       2.50
# 1008        1008  1624079104  20150402T000000  540000.0       3.0       2.25
# 1009        1009  4310700570  20141210T000000  280300.0       2.0       1.00
# ...

# %%
bedrooms_rec = rooms_record.bedrooms
bedrooms_rec
# Out:
# 0        3.0
# 1        3.0
# 2        2.0
# 3        4.0
# 4        3.0
#         ...
# 21608    3.0
# 21609    4.0
# 21610    2.0
# 21611    3.0
# 21612    2.0
# Name: bedrooms, Length: 21613, dtype: float64

# %%
rooms_record.at[2, 'bedrooms_rec']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Muhammad Ali khan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Muhammad Ali khan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Muhammad Ali khan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
bd3 = rooms_record.at[3, 'bedrooms']
# Out:
# 4.0

# %%
min2 = rooms_record['bedrooms==2'].min()

# %%
max2= rooms_record['bedrooms==2'].max()

# %%
min3 = rooms_record['bedrooms==3'].min()

# %%
sbr2 = rooms_record['bd2'].sum()
avrbd2 = sbr2/
sbr3 = rooms_record['bd3'].sum()
avrbd3 = sbr3/
